# %%
# ===============================
# Install compatible libraries
# ===============================
# !pip uninstall -y scikit-learn umap-learn cuml-cu12 || true

# !pip install -U \
    scikit-learn==1.4.2 \
    tensorflow==2.19.0 \
    ml_dtypes>=0.5.0 \
    opencv-python \
    seaborn \
    matplotlib \
    tqdm \
    tensorflow-hub \
    imbalanced-learn

# Verify versions
import sklearn, tensorflow as tf
print("✅ scikit-learn:", sklearn.__version__)
print("✅ TensorFlow:", tf.__version__)
# Out:
# Found existing installation: scikit-learn 1.4.2
# Uninstalling scikit-learn-1.4.2:
#   Successfully uninstalled scikit-learn-1.4.2
# WARNING: Skipping umap-learn as it is not installed.
# WARNING: Skipping cuml-cu12 as it is not installed.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# hdbscan 0.8.41 requires scikit-learn>=1.6, but you have scikit-learn 1.4.2 which is incompatible.
# ✅ scikit-learn: 1.4.2
# ✅ TensorFlow: 2.19.0

# %%
# ===============================
# General & Data Libraries
# ===============================
import os, glob, json, random, warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense,
    Dropout, BatchNormalization
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import load_img, img_to_array, to_categorical

# Image processing
import cv2
from tqdm import tqdm

# Data balancing
from imblearn.over_sampling import RandomOverSampler

# Visualization
sns.set_style("darkgrid")
warnings.filterwarnings("ignore")

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("✅ Imports & seeds set")
# Out:
# ✅ Imports & seeds set

# %%
from google.colab import drive

print("⚙️ Mounting Drive...")
drive.mount('/content/drive')
print("✅ Drive mounted")

# ===============================
# Paths & Constants
# ===============================
DATA_ROOTS = [
    "/content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone 2.0/Breast Cancer New Dataset"
]

OUT_DIR = "/content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API"
os.makedirs(OUT_DIR, exist_ok=True)

IMG_SIZE   = (224, 224)
BATCH_SIZE = 64

CLASSES = ["normal", "benign", "malignant"]
class_to_idx = {c: i for i, c in enumerate(CLASSES)}
idx_to_class = {i: c for c, i in class_to_idx.items()}

print("✅ Paths & constants ready")
# Out:
# ⚙️ Mounting Drive...
# Mounted at /content/drive
# ✅ Drive mounted
# ✅ Paths & constants ready

# %%
# -------------------------
# 1) Dataset collection (re-added)
# -------------------------
import os, glob, random
import numpy as np
from collections import Counter
import cv2
import tensorflow as tf # Required for tf.TensorSpec
from tensorflow.keras.utils import to_categorical # Required for one-hot encoding
from imblearn.over_sampling import RandomOverSampler # Required for data balancing
from sklearn.model_selection import train_test_split

# Define paths and constants locally for self-containment
DATA_ROOTS = [
    "/content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone 2.0/Breast Cancer New Dataset"
]
IMG_SIZE   = (224, 224)
BATCH_SIZE = 64
CLASSES = ["normal", "benign", "malignant"]
class_to_idx = {c: i for i, c in enumerate(CLASSES)}
idx_to_class = {i: c for c, i in class_to_idx.items()}
SEED = 42 # Added SEED definition for self-containment

def is_mask_path(p):
    name = os.path.basename(p).lower()
    return ("mask" in name) or name.endswith("_mask.png") or name.endswith("_gt.png")

def collect_dataset(data_roots):
    paths, labels, mask_paths = [], [], []
    for root in data_roots:
        for cls in CLASSES:
            cdir = os.path.join(root, cls)
            if not os.path.isdir(cdir):
                continue
            imgs = []
            for ext in ("*.png","*.jpg","*.jpeg"):
                imgs += glob.glob(os.path.join(cdir, ext))
            imgs = [p for p in imgs if not is_mask_path(p)]
            for p in imgs:
                stem = os.path.splitext(os.path.basename(p))[0].lower()
                folder = os.path.dirname(p)
                mask = ""
                for ext in ("*.png","*.jpg","*.jpeg"):
                    for m in glob.glob(os.path.join(folder, ext)):
                        if "mask" in m.lower() and stem in m.lower():
                            mask = m
                            break
                paths.append(p)
                labels.append(class_to_idx[cls])
                mask_paths.append(mask)
    return np.array(paths), np.array(labels), np.array(mask_paths)

paths, labels, mask_paths = collect_dataset(DATA_ROOTS)
assert len(paths)>0, "❌ No images found. Check DATA_ROOTS or class folder names!"
print(f"🧾 Total images: {len(paths)} | mask coverage \u2248 {np.mean(mask_paths!='')*100:.1f}%")

# ------------------------- Original code begins here
# 2) Split dataset
# -------------------------
X_temp, X_test, y_temp, y_test, m_temp, m_test = train_test_split(
    paths, labels, mask_paths, test_size=0.15, stratify=labels, random_state=SEED
)
X_train, X_val, y_train, y_val, m_train, m_val = train_test_split(
    X_temp, y_temp, m_temp, test_size=0.1765, stratify=y_temp, random_state=SEED
)
print(f"Split \u2192 train={len(X_train)} | val={len(X_val)} | test={len(X_test)}")

# -------------------------
# 2.1) Balance training data using RandomOverSampler (New)
# -------------------------
print("Balancing training data...")
ros = RandomOverSampler(random_state=SEED)
# Reshape X_train (paths, masks) for oversampler, then unpack
X_train_resampled_indices, y_train_resampled = ros.fit_resample(np.arange(len(X_train)).reshape(-1, 1), y_train)
X_train_resampled_indices = X_train_resampled_indices.flatten()

X_train_bal = X_train[X_train_resampled_indices]
y_train_bal = y_train_resampled
m_train_bal = m_train[X_train_resampled_indices]

print(f"Original training class distribution: {Counter(y_train)}")
print(f"Resampled training class distribution: {Counter(y_train_bal)}")

# -------------------------
# 2.2) One-hot encode labels (New)
# -------------------------
num_classes = len(CLASSES)
y_train_ohe = to_categorical(y_train_bal, num_classes=num_classes)
y_val_ohe   = to_categorical(y_val, num_classes=num_classes)
y_test_ohe  = to_categorical(y_test, num_classes=num_classes)
print("Labels one-hot encoded.")


# -------------------------
# 3) Helper functions
# -------------------------
def load_image_bgr(path):
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    return img if img is not None else np.zeros((224,224,3), np.uint8)

def load_mask(mask_path, base_img):
    if mask_path and os.path.exists(mask_path):
        m = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        _, mb = cv2.threshold(m, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
        return (mb>0).astype(np.uint8)
    else:
        return np.zeros(base_img.shape[:2], np.uint8)

def roi_from_mask(img_bgr, mask_bin):
    if mask_bin.sum()==0: return img_bgr
    ys, xs = np.where(mask_bin>0)
    y0, y1 = max(ys.min()-10,0), min(ys.max()+10, img_bgr.shape[0]-1)
    x0, x1 = max(xs.min()-10,0), min(xs.max()+10, img_bgr.shape[1]-1)
    return img_bgr[y0:y1+1, x0:x1+1]

def to_tensor(img_bgr, size=IMG_SIZE):
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    img_rgb = cv2.resize(img_rgb, size, interpolation=cv2.INTER_AREA)
    return img_rgb.astype(np.float32)/255.0

# -------------------------
# 4) Dataset generator
# -------------------------
def gen_dataset(X, y_ohe, M, training=True):
    idxs = np.arange(len(X))
    if training: np.random.shuffle(idxs)
    for i in idxs:
        img = load_image_bgr(X[i])
        mask = load_mask(M[i], img)
        roi = roi_from_mask(img, mask)
        arr = to_tensor(roi)
        if training:
            if random.random()<0.5: arr = arr[:, ::-1, :]
            if random.random()<0.2: arr = np.clip(arr + np.random.uniform(-0.08,0.08), 0,1)
        yield arr, y_ohe[i]

sig = (tf.TensorSpec(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), dtype=tf.float32),
       tf.TensorSpec(shape=(num_classes,), dtype=tf.float32)) # Updated for one-hot encoding

def build_tfds(X, y_ohe, M, training):
    ds = tf.data.Dataset.from_generator(lambda: gen_dataset(X,y_ohe,M,training), output_signature=sig)
    if training: ds = ds.shuffle(1024)
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

ds_train = build_tfds(X_train_bal, y_train_ohe, m_train_bal, True)
ds_val   = build_tfds(X_val,   y_val_ohe,   m_val,   False)
ds_test  = build_tfds(X_test,  y_test_ohe,  m_test,  False)
# Out:
# 🧾 Total images: 8088 | mask coverage ≈ 0.0%
# Split → train=5660 | val=1214 | test=1214
# Balancing training data...
# Original training class distribution: Counter({np.int64(2): 2049, np.int64(1): 1948, np.int64(0): 1663})
# Resampled training class distribution: Counter({np.int64(2): 2049, np.int64(1): 2049, np.int64(0): 2049})
# Labels one-hot encoded.

# %%
# ===============================
# 5) Define Custom CNN Model
# ===============================

# Ensure IMG_SIZE and CLASSES are defined in this scope
IMG_SIZE   = (224, 224)
CLASSES = ["normal", "benign", "malignant"]

# Explicitly import Keras components needed in this cell
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
import tensorflow.keras as keras # Added this import

def create_cnn_model(input_shape, num_classes, l2_reg=0.001):
    model = Sequential([
        # First Convolutional Block
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape, padding='same',
               kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        # Second Convolutional Block
        Conv2D(64, (3, 3), activation='relu', padding='same',
               kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        # Third Convolutional Block
        Conv2D(128, (3, 3), activation='relu', padding='same',
               kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        # Flatten and Dense Layers
        Flatten(),
        Dense(256, activation='relu', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# Instantiate and compile the custom CNN model
custom_cnn_model = create_cnn_model(IMG_SIZE + (3,), num_classes=len(CLASSES))

custom_cnn_model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

custom_cnn_model.summary()
print("✅ Custom CNN model with L2 regularization defined and compiled.")

# Note: This model is separate from the EfficientNetB3 model in a later cell.
# If you intend to use this custom CNN for training, you will need to replace
# 'model' and its training calls in subsequent cells with 'custom_cnn_model'.
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    25,690,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,786,307 (98.37 MB)
#  Trainable params: 25,785,347 (98.36 MB)
#  Non-trainable params: 960 (3.75 KB)
# ✅ Custom CNN model with L2 regularization defined and compiled.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import pandas as pd

# --- Visualize Class Distribution Before Balancing ---
original_class_counts = Counter(labels)
original_df = pd.DataFrame({
    'Class': [idx_to_class[i] for i in original_class_counts.keys()],
    'Count': list(original_class_counts.values())
}).sort_values(by='Class')

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.barplot(x='Class', y='Count', data=original_df, hue='Class', palette='viridis', legend=False)
plt.title('Class Distribution Before Balancing (Full Dataset)')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45, ha='right')

# --- Visualize Class Distribution After Balancing ---
balanced_class_counts = Counter(y_train_bal)
balanced_df = pd.DataFrame({
    'Class': [idx_to_class[i] for i in balanced_class_counts.keys()],
    'Count': list(balanced_class_counts.values())
}).sort_values(by='Class')

plt.subplot(1, 2, 2)
sns.barplot(x='Class', y='Count', data=balanced_df, hue='Class', palette='viridis', legend=False)
plt.title('Class Distribution After Balancing (Training Set)')
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.applications import VGG16
import os

# Imports needed for the train_and_evaluate_model function
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf # For tf.argmax

def train_and_evaluate_model(
    base_model_constructor,
    model_name,
    checkpoint_path,
    IMG_SIZE,
    CLASSES,
    num_classes,
    ds_train,
    ds_val,
    ds_test,
    y_test_ohe # This is only used for classification report, not model training/evaluation directly
):
    print(f"\n--- Training {model_name} Model ---")

    # 1. Load base model
    base_model = base_model_constructor(
        input_shape=IMG_SIZE + (3,),
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = False # Freeze the base model weights initially

    # 2. Add custom classification layers
    x = base_model.output
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # 3. Compile the model
    model.compile(
        optimizer=Adam(learning_rate=1e-4), # Use a lower learning rate for transfer learning
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # 4. Callbacks
    callbacks = [
        ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
    ]

    # 5. Train the model
    history = model.fit(
        ds_train,
        validation_data=ds_val,
        epochs=50, # Set a reasonable maximum number of epochs
        callbacks=callbacks
    )

    # 6. Evaluate the model
    print(f"\n--- Evaluating {model_name} Model ---")
    model.load_weights(checkpoint_path) # Load best weights for evaluation
    loss, accuracy = model.evaluate(ds_test)
    print(f"Test Loss: {loss:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")

    # Generate classification report and confusion matrix
    y_pred_probs = model.predict(ds_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test_ohe, axis=1) # y_test_ohe is expected as a numpy array here

    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=CLASSES))

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES)
    plt.title(f'Confusion Matrix for {model_name}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    return model, history

vgg_model_name = "VGG16"
vgg_checkpoint_path = os.path.join(OUT_DIR, "vgg16_best.keras")

best_vgg_model, history_vgg = train_and_evaluate_model(
    base_model_constructor=VGG16,
    model_name=vgg_model_name,
    checkpoint_path=vgg_checkpoint_path,
    IMG_SIZE=IMG_SIZE,
    CLASSES=CLASSES,
    num_classes=num_classes,
    ds_train=ds_train,
    ds_val=ds_val,
    ds_test=ds_test,
    y_test_ohe=y_test_ohe
)
# Out:
# --- Training VGG16 Model ---
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
#      97/Unknown 2322s 19s/step - accuracy: 0.5211 - loss: 1.0274
# Epoch 1: val_loss improved from inf to 0.78576, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2848s 25s/step - accuracy: 0.5218 - loss: 1.0260 - val_accuracy: 0.6614 - val_loss: 0.7858 - learning_rate: 1.0000e-04
# Epoch 2/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6890 - loss: 0.7312
# Epoch 2: val_loss improved from 0.78576 to 0.61930, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.6894 - loss: 0.7306 - val_accuracy: 0.7488 - val_loss: 0.6193 - learning_rate: 1.0000e-04
# Epoch 3/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7327 - loss: 0.6499
# Epoch 3: val_loss improved from 0.61930 to 0.60385, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.7329 - loss: 0.6496 - val_accuracy: 0.7545 - val_loss: 0.6038 - learning_rate: 1.0000e-04
# Epoch 4/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7491 - loss: 0.6085
# Epoch 4: val_loss improved from 0.60385 to 0.59305, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.7493 - loss: 0.6082 - val_accuracy: 0.7488 - val_loss: 0.5930 - learning_rate: 1.0000e-04
# Epoch 5/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7666 - loss: 0.5795
# Epoch 5: val_loss improved from 0.59305 to 0.52113, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.7669 - loss: 0.5790 - val_accuracy: 0.7916 - val_loss: 0.5211 - learning_rate: 1.0000e-04
# Epoch 6/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7849 - loss: 0.5397
# Epoch 6: val_loss improved from 0.52113 to 0.51746, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.7850 - loss: 0.5393 - val_accuracy: 0.7900 - val_loss: 0.5175 - learning_rate: 1.0000e-04
# Epoch 7/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7965 - loss: 0.5078
# Epoch 7: val_loss did not improve from 0.51746
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.7965 - loss: 0.5078 - val_accuracy: 0.7858 - val_loss: 0.5308 - learning_rate: 1.0000e-04
# Epoch 8/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7771 - loss: 0.5308
# Epoch 8: val_loss improved from 0.51746 to 0.49726, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.7774 - loss: 0.5302 - val_accuracy: 0.7900 - val_loss: 0.4973 - learning_rate: 1.0000e-04
# Epoch 9/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8185 - loss: 0.4613
# Epoch 9: val_loss improved from 0.49726 to 0.48518, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.8185 - loss: 0.4611 - val_accuracy: 0.7924 - val_loss: 0.4852 - learning_rate: 1.0000e-04
# Epoch 10/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8284 - loss: 0.4496
# Epoch 10: val_loss did not improve from 0.48518
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.8284 - loss: 0.4494 - val_accuracy: 0.7669 - val_loss: 0.5618 - learning_rate: 1.0000e-04
# Epoch 11/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8097 - loss: 0.4735
# Epoch 11: val_loss improved from 0.48518 to 0.46446, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8100 - loss: 0.4728 - val_accuracy: 0.8023 - val_loss: 0.4645 - learning_rate: 1.0000e-04
# Epoch 12/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8440 - loss: 0.4008
# Epoch 12: val_loss did not improve from 0.46446
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.8441 - loss: 0.4008 - val_accuracy: 0.8064 - val_loss: 0.4676 - learning_rate: 1.0000e-04
# Epoch 13/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8402 - loss: 0.4055
# Epoch 13: val_loss did not improve from 0.46446
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.8404 - loss: 0.4052 - val_accuracy: 0.7883 - val_loss: 0.4957 - learning_rate: 1.0000e-04
# Epoch 14/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8284 - loss: 0.4404
# Epoch 14: val_loss improved from 0.46446 to 0.43898, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.8287 - loss: 0.4397 - val_accuracy: 0.8155 - val_loss: 0.4390 - learning_rate: 1.0000e-04
# Epoch 15/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8671 - loss: 0.3532
# Epoch 15: val_loss improved from 0.43898 to 0.43563, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.8670 - loss: 0.3536 - val_accuracy: 0.8163 - val_loss: 0.4356 - learning_rate: 1.0000e-04
# Epoch 16/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8586 - loss: 0.3722
# Epoch 16: val_loss improved from 0.43563 to 0.41990, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.8586 - loss: 0.3722 - val_accuracy: 0.8213 - val_loss: 0.4199 - learning_rate: 1.0000e-04
# Epoch 17/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8685 - loss: 0.3523
# Epoch 17: val_loss did not improve from 0.41990
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8685 - loss: 0.3523 - val_accuracy: 0.8204 - val_loss: 0.4238 - learning_rate: 1.0000e-04
# Epoch 18/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8781 - loss: 0.3320
# Epoch 18: val_loss did not improve from 0.41990
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.8782 - loss: 0.3319 - val_accuracy: 0.7941 - val_loss: 0.4642 - learning_rate: 1.0000e-04
# Epoch 19/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8507 - loss: 0.3704
# Epoch 19: val_loss did not improve from 0.41990
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.8510 - loss: 0.3698 - val_accuracy: 0.8081 - val_loss: 0.4271 - learning_rate: 1.0000e-04
# Epoch 20/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8742 - loss: 0.3515
# Epoch 20: val_loss improved from 0.41990 to 0.41074, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8742 - loss: 0.3514 - val_accuracy: 0.8254 - val_loss: 0.4107 - learning_rate: 1.0000e-04
# Epoch 21/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8790 - loss: 0.3254
# Epoch 21: val_loss did not improve from 0.41074
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.8790 - loss: 0.3253 - val_accuracy: 0.8180 - val_loss: 0.4141 - learning_rate: 1.0000e-04
# Epoch 22/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8881 - loss: 0.3108
# Epoch 22: val_loss improved from 0.41074 to 0.39929, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.8881 - loss: 0.3107 - val_accuracy: 0.8328 - val_loss: 0.3993 - learning_rate: 1.0000e-04
# Epoch 23/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8913 - loss: 0.2943
# Epoch 23: val_loss did not improve from 0.39929
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.8913 - loss: 0.2943 - val_accuracy: 0.8188 - val_loss: 0.4081 - learning_rate: 1.0000e-04
# Epoch 24/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8824 - loss: 0.3071
# Epoch 24: val_loss improved from 0.39929 to 0.39509, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8825 - loss: 0.3068 - val_accuracy: 0.8320 - val_loss: 0.3951 - learning_rate: 1.0000e-04
# Epoch 25/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9023 - loss: 0.2707
# Epoch 25: val_loss improved from 0.39509 to 0.39400, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9022 - loss: 0.2708 - val_accuracy: 0.8213 - val_loss: 0.3940 - learning_rate: 1.0000e-04
# Epoch 26/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8942 - loss: 0.2896
# Epoch 26: val_loss did not improve from 0.39400
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8943 - loss: 0.2893 - val_accuracy: 0.8245 - val_loss: 0.3946 - learning_rate: 1.0000e-04
# Epoch 27/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9081 - loss: 0.2509
# Epoch 27: val_loss improved from 0.39400 to 0.38469, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9080 - loss: 0.2512 - val_accuracy: 0.8369 - val_loss: 0.3847 - learning_rate: 1.0000e-04
# Epoch 28/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8922 - loss: 0.2903
# Epoch 28: val_loss did not improve from 0.38469
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8925 - loss: 0.2898 - val_accuracy: 0.8221 - val_loss: 0.4150 - learning_rate: 1.0000e-04
# Epoch 29/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9138 - loss: 0.2369
# Epoch 29: val_loss did not improve from 0.38469
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9138 - loss: 0.2371 - val_accuracy: 0.8163 - val_loss: 0.4292 - learning_rate: 1.0000e-04
# Epoch 30/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9008 - loss: 0.2692
# Epoch 30: val_loss did not improve from 0.38469
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9010 - loss: 0.2687 - val_accuracy: 0.8221 - val_loss: 0.3900 - learning_rate: 1.0000e-04
# Epoch 31/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9201 - loss: 0.2234
# Epoch 31: val_loss did not improve from 0.38469
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9201 - loss: 0.2234 - val_accuracy: 0.8221 - val_loss: 0.3901 - learning_rate: 1.0000e-04
# Epoch 32/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8966 - loss: 0.2730
# Epoch 32: val_loss improved from 0.38469 to 0.37958, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.8968 - loss: 0.2726 - val_accuracy: 0.8369 - val_loss: 0.3796 - learning_rate: 1.0000e-04
# Epoch 33/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9136 - loss: 0.2353
# Epoch 33: val_loss improved from 0.37958 to 0.36652, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9137 - loss: 0.2352 - val_accuracy: 0.8468 - val_loss: 0.3665 - learning_rate: 1.0000e-04
# Epoch 34/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9117 - loss: 0.2393
# Epoch 34: val_loss did not improve from 0.36652
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9118 - loss: 0.2391 - val_accuracy: 0.8427 - val_loss: 0.3706 - learning_rate: 1.0000e-04
# Epoch 35/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9252 - loss: 0.2123
# Epoch 35: val_loss improved from 0.36652 to 0.36600, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9253 - loss: 0.2123 - val_accuracy: 0.8517 - val_loss: 0.3660 - learning_rate: 1.0000e-04
# Epoch 36/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9270 - loss: 0.2066
# Epoch 36: val_loss improved from 0.36600 to 0.35956, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9270 - loss: 0.2067 - val_accuracy: 0.8501 - val_loss: 0.3596 - learning_rate: 1.0000e-04
# Epoch 37/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9312 - loss: 0.1985
# Epoch 37: val_loss improved from 0.35956 to 0.35200, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 0.9312 - loss: 0.1987 - val_accuracy: 0.8493 - val_loss: 0.3520 - learning_rate: 1.0000e-04
# Epoch 38/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9326 - loss: 0.1937
# Epoch 38: val_loss did not improve from 0.35200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9326 - loss: 0.1937 - val_accuracy: 0.8377 - val_loss: 0.3677 - learning_rate: 1.0000e-04
# Epoch 39/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9157 - loss: 0.2196
# Epoch 39: val_loss did not improve from 0.35200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9160 - loss: 0.2193 - val_accuracy: 0.8262 - val_loss: 0.4033 - learning_rate: 1.0000e-04
# Epoch 40/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8999 - loss: 0.2586
# Epoch 40: val_loss did not improve from 0.35200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9003 - loss: 0.2579 - val_accuracy: 0.8336 - val_loss: 0.3752 - learning_rate: 1.0000e-04
# Epoch 41/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9365 - loss: 0.1946
# Epoch 41: val_loss did not improve from 0.35200
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9366 - loss: 0.1944 - val_accuracy: 0.8517 - val_loss: 0.3584 - learning_rate: 1.0000e-04
# Epoch 42/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9352 - loss: 0.1865
# Epoch 42: val_loss did not improve from 0.35200
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9352 - loss: 0.1864 - val_accuracy: 0.8336 - val_loss: 0.3834 - learning_rate: 1.0000e-04
# Epoch 43/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9417 - loss: 0.1726
# Epoch 43: val_loss improved from 0.35200 to 0.34762, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9418 - loss: 0.1724 - val_accuracy: 0.8550 - val_loss: 0.3476 - learning_rate: 5.0000e-05
# Epoch 44/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9541 - loss: 0.1554
# Epoch 44: val_loss did not improve from 0.34762
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9541 - loss: 0.1553 - val_accuracy: 0.8460 - val_loss: 0.3545 - learning_rate: 5.0000e-05
# Epoch 45/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9506 - loss: 0.1538
# Epoch 45: val_loss did not improve from 0.34762
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9506 - loss: 0.1538 - val_accuracy: 0.8402 - val_loss: 0.3639 - learning_rate: 5.0000e-05
# Epoch 46/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9577 - loss: 0.1479
# Epoch 46: val_loss did not improve from 0.34762
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9576 - loss: 0.1480 - val_accuracy: 0.8558 - val_loss: 0.3519 - learning_rate: 5.0000e-05
# Epoch 47/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9543 - loss: 0.1474
# Epoch 47: val_loss did not improve from 0.34762
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9543 - loss: 0.1474 - val_accuracy: 0.8484 - val_loss: 0.3584 - learning_rate: 5.0000e-05
# Epoch 48/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9619 - loss: 0.1413
# Epoch 48: val_loss did not improve from 0.34762
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9618 - loss: 0.1413 - val_accuracy: 0.8493 - val_loss: 0.3515 - learning_rate: 5.0000e-05
# Epoch 49/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9598 - loss: 0.1399
# Epoch 49: val_loss did not improve from 0.34762
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9598 - loss: 0.1398 - val_accuracy: 0.8608 - val_loss: 0.3503 - learning_rate: 2.5000e-05
# Epoch 50/50
# 96/97 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9637 - loss: 0.1286
# Epoch 50: val_loss improved from 0.34762 to 0.34749, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Capstone/Breast_Models_API/vgg16_best.keras
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9637 - loss: 0.1286 - val_accuracy: 0.8583 - val_loss: 0.3475 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 50.
#
# --- Evaluating VGG16 Model ---
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 486s 25s/step - accuracy: 0.8511 - loss: 0.3567
# Test Loss: 0.3883
# Test Accuracy: 0.8451
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       normal       0.88      0.92      0.90       357
#       benign       0.80      0.79      0.80       418
#    malignant       0.86      0.83      0.85       439
#
#     accuracy                           0.85      1214
#    macro avg       0.85      0.85      0.85      1214
# weighted avg       0.84      0.85      0.84      1214

# %%
history = history_vgg

plt.figure(figsize=(12, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
